# %%
#import dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#read csv 
animal_data = pd.read_csv("Austin_Animal_Center_Intakes.csv", sep=',', encoding='latin-1')
animal_data.head()
# Out:
#   Animal ID         DateTime        MonthYear  \
# 0   A748291   5/1/2017 14:26   5/1/2017 14:26
# 1   A750529  5/28/2017 13:22  5/28/2017 13:22
# 2   A730601   7/7/2016 12:11   7/7/2016 12:11
# 3   A748238   5/1/2017 10:53   5/1/2017 10:53
# 4   A683644  7/13/2014 11:02  7/13/2014 11:02
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                    8312 North Ih 35 in Austin (TX)            Stray
# 2                       1109 Shady Ln in Austin (TX)            Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 4                                        Austin (TX)  Owner Surrender
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0           Normal         Dog   Intact Female       10 months
# 1           Normal         Dog   Intact Female        5 months
# 2           Normal         Cat     Intact Male        7 months
# ...

# %%
Total = animal_data.groupby[''].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CatsAdopt'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-f92d9747bcc1> in <module>()
# ----> 1 Total = animal_data['CatsAdopt'].sum()
# ...
